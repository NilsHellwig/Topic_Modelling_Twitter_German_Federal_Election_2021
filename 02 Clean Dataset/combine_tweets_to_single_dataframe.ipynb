# %% [markdown]
# # Notebook: Combine Tweets to one Dataframe

# %% [markdown]
# ## 1. Load Packages

# %%
from load_datasets import load_mentions_dataset, load_political_accounts_dataset
#from gensim.models.ldamodel import LdaModel
#from nltk.tokenize import word_tokenize
#from gensim.corpora import Dictionary
#from nltk.corpus import stopwords
#from gensim import corpora
#import pandas as pd
#import gensim
#import spacy
#import nltk
#import re
#import os

# %% [markdown]
# ## 2. Constants / Setup

# %%
DATASET_MENTIONS_PATH = "../Datasets/tweets_mentions.csv"
DATASET_POLITICAL_ACCOUNTS_PATH = "../Datasets/tweets_political_accounts.csv"

# %% [markdown]
# ## 3. Load Dataset

# %%
df_mentions = load_mentions_dataset()

# %%
df_mentions
# Out:
#                                                      text source_party
# 0       Wichtige wissenschaftliche Erkenntnis- nun mus...          SPD  \
# 1       @KarambaDiaby @HalleSpd @SPD_LSA Ich gratulier...          SPD
# 2       @KarambaDiaby @HalleSpd @SPD_LSA Herzlichen Gl...          SPD
# 3       @KarambaDiaby @HalleSpd @SPD_LSA Wann werden k...          SPD
# 4           @KarambaDiaby @HalleSpd @SPD_LSA Glückwunsch.          SPD
# ...                                                   ...          ...
# 707236  @b_riexinger Klima oder Verkehr fast gleich......        LINKE
# 707237  @b_riexinger @Linksfraktion Na ob das noch lan...        LINKE
# 707238           @b_riexinger Ich wünsch Dir viel Erfolg.        LINKE
# 707239  @b_riexinger Nun, da gibt es ja genügend zu tu...        LINKE
# 707240  @b_riexinger Wünsche dir gutes Gelingen lieber...        LINKE
#
#        source_account                 date  sentiment
# 0        KarambaDiaby  2021-01-09 19:35:29          0
# ...

# %%
df_political_accounts = load_political_accounts_dataset()

# %%
df_political_accounts
# Out:
#        UserScreenName  source_account                 date
# 0          AfD Berlin       AfDBerlin  2021-03-26 21:07:22  \
# 1          AfD Berlin       AfDBerlin  2021-03-27 07:20:27
# 2          AfD Berlin       AfDBerlin  2021-03-31 07:14:04
# 3          AfD Berlin       AfDBerlin  2021-04-01 14:29:00
# 4          AfD Berlin       AfDBerlin  2021-04-01 05:02:10
# ...               ...             ...                  ...
# 58859  Tino Chrupalla  Tino_Chrupalla  2021-12-04 17:26:46
# 58860  Tino Chrupalla  Tino_Chrupalla  2021-12-13 16:30:19
# 58861  Tino Chrupalla  Tino_Chrupalla  2021-12-17 14:02:24
# 58862  Tino Chrupalla  Tino_Chrupalla  2021-12-19 09:27:23
# 58863  Tino Chrupalla  Tino_Chrupalla  2021-12-23 13:40:49
#
#                                                     Text
# 0                    AfD Berlin\n@AfDBerlin\n·\n26. März  \
# 1                    AfD Berlin\n@AfDBerlin\n·\n27. März
# 2                    AfD Berlin\n@AfDBerlin\n·\n31. März
# ...

# %% [markdown]
# ## 4. Code

# %%
df_mentions.to_csv(DATASET_MENTIONS_PATH)
df_political_accounts.to_csv(DATASET_POLITICAL_ACCOUNTS_PATH)
